# %% [markdown]
# ## Connect with the GoogleDrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Import all the modules

# %%
import os
import glob
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import json
import tensorflow.keras as keras
import tensorflow.keras.optimizers as optimizers
from sklearn.utils import shuffle

# %% [markdown]
# # Load training HW data and assign labels for each data sample (`[1]`)

# %%
#folder_path = '/content/drive/MyDrive/project/Training_MS_dB/HW'
folder_path = '/content/drive/MyDrive/project/Training_MS_PCEN/HW'
#folder_path = '/content/drive/MyDrive/project/Training_MS_PCEN_default/HW'

png_files = glob.glob(os.path.join(folder_path, '*.png'))

images_as_arrays = []
count = 1
for file in png_files:
    with Image.open(file) as img:
        img_array = np.array(img)
        print(f"The data sample {file} is processed: {count}/{len(os.listdir(folder_path))}")
        count = count+1
        images_as_arrays.append(img_array)

training_images_HW = np.asarray(images_as_arrays)
training_labels_HW = np.ones(training_images_HW.shape[0])
# Out:
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53B5710D_90.png is processed: 1/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/5394B3CD_0.png is processed: 2/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53FD1612_190.png is processed: 3/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/54053057_200.png is processed: 4/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53FD1612_0.png is processed: 5/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53B02082_0.png is processed: 6/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53DD16A9_70.png is processed: 7/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53F45319_90.png is processed: 8/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53D81E01_200.png is processed: 9/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/5403014D_150.png is processed: 10/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53B02082_150.png is processed: 11/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53A9FD05_250.png is processed: 12/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53FAF1A1_230.png is processed: 13/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/539C7D29_50.png is processed: 14/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53B5710D_150.png is processed: 15/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53FAF1A1_280.png is processed: 16/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/54073FA2_100.png is processed: 17/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53D81E01_0.png is processed: 18/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53DD16A9_250.png is processed: 19/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/540FCDDD_80.png is processed: 20/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/5394B3CD_90.png is processed: 21/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53E94889_100.png is processed: 22/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53E0901E_150.png is processed: 23/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53E0EF08_200.png is processed: 24/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53D3BC86_150.png is processed: 25/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53E0EF08_100.png is processed: 26/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/540F5D5C_150.png is processed: 27/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53A9FD05_120.png is processed: 28/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53CFB672_250.png is processed: 29/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/54074325_210.png is processed: 30/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53DEAAF5_20.png is processed: 31/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53E07E8A_10.png is processed: 32/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53FAE396_60.png is processed: 33/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53D7CD25_150.png is processed: 34/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/540E0859_110.png is processed: 35/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53D81E01_150.png is processed: 36/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/54073FA2_250.png is processed: 37/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/539ED2D2_10.png is processed: 38/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53DD16A9_150.png is processed: 39/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/5408E581_40.png is processed: 40/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/540754BA_150.png is processed: 41/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/5394CFEC_100.png is processed: 42/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/539C7D29_190.png is processed: 43/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53B3340A_40.png is processed: 44/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53D42981_0.png is processed: 45/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/5394D6F5_150.png is processed: 46/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/5408E581_0.png is processed: 47/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53FAE396_100.png is processed: 48/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53E0EF08_160.png is processed: 49/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/5408E581_100.png is processed: 50/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53FCDDD1_100.png is processed: 51/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/54074325_0.png is processed: 52/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53E9FF59_150.png is processed: 53/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53F12E05_240.png is processed: 54/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/540A13D9_200.png is processed: 55/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53E94889_0.png is processed: 56/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53E44C5D_0.png is processed: 57/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53FD1612_70.png is processed: 58/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/540F5D5C_210.png is processed: 59/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/5398C46C_100.png is processed: 60/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53F48B59_120.png is processed: 61/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/540754BA_100.png is processed: 62/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/540FCDDD_160.png is processed: 63/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/539A90FA_240.png is processed: 64/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53E16A15_50.png is processed: 65/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/539C7D29_0.png is processed: 66/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/539A00D4_120.png is processed: 67/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/540F332D_250.png is processed: 68/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53A76B99_200.png is processed: 69/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/540BC445_20.png is processed: 70/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53CFB672_200.png is processed: 71/355
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/53E
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/HW/542E00B9_0.png is processed: 355/355

# %%
import gc
gc.collect()
del img_resized, img_array, images_as_arrays
gc.collect()
# Out:
# 0

# %% [markdown]
# # Load training NoHW data and assign labels for each data sample (`[0]`)

# %%
#folder_path = '/content/drive/MyDrive/project/Training_MS_dB/NoHW'
folder_path = '/content/drive/MyDrive/project/Training_MS_PCEN/NoHW'
#folder_path = '/content/drive/MyDrive/project/Training_MS_PCEN_default/NoHW'


png_files = glob.glob(os.path.join(folder_path, '*.png'))

images_as_arrays = []
count = 1
for file in png_files:
    with Image.open(file) as img:
        img_array = np.array(img)
        print(f"The data sample {file} is processed: {count}/{len(os.listdir(folder_path))}")
        count = count+1
        images_as_arrays.append(img_array)

training_images_NoHW = np.asarray(images_as_arrays)
training_labels_NoHW = np.zeros(training_images_NoHW.shape[0])
# Out:
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/53395659_0.png is processed: 1/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52FD5696_130.png is processed: 2/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/53418225_20.png is processed: 3/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/53258FD9_200.png is processed: 4/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52C613B6_60.png is processed: 5/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5342783C_250.png is processed: 6/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52BF9F5D_230.png is processed: 7/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/531E05C5_70.png is processed: 8/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52F48C96_180.png is processed: 9/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/533B0341_30.png is processed: 10/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5306D765_260.png is processed: 11/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5306D765_0.png is processed: 12/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52C79D75_150.png is processed: 13/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5306D765_140.png is processed: 14/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52F694E5_100.png is processed: 15/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/53430F69_160.png is processed: 16/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52F0B0B1_180.png is processed: 17/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52CEE4BD_150.png is processed: 18/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52B91CF6_230.png is processed: 19/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/53430F69_270.png is processed: 20/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52ED3E45_180.png is processed: 21/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/530120E6_180.png is processed: 22/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/533D66FA_30.png is processed: 23/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/53443335_30.png is processed: 24/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/53395659_50.png is processed: 25/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52CDE419_0.png is processed: 26/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/530120E6_140.png is processed: 27/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/53430F69_30.png is processed: 28/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5316B776_0.png is processed: 29/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/530E17A5_60.png is processed: 30/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5330541A_130.png is processed: 31/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/532C4A82_20.png is processed: 32/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/531ED531_190.png is processed: 33/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52EF317D_60.png is processed: 34/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5319A448_70.png is processed: 35/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52D31C09_30.png is processed: 36/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5306DE6D_20.png is processed: 37/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/53395659_210.png is processed: 38/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52D5B47D_90.png is processed: 39/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52ED5A65_0.png is processed: 40/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5321DE25_120.png is processed: 41/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52CEBE10_170.png is processed: 42/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52B6D1D9_220.png is processed: 43/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5337FDD1_190.png is processed: 44/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5337194D_60.png is processed: 45/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52D0D7F4_40.png is processed: 46/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52BAFE99_20.png is processed: 47/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52FC283D_200.png is processed: 48/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52EED615_130.png is processed: 49/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52D6A009_190.png is processed: 50/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/53395659_100.png is processed: 51/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52ED5A65_200.png is processed: 52/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/532D2479_50.png is processed: 53/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5338C635_100.png is processed: 54/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/531A7E41_120.png is processed: 55/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52B679F5_0.png is processed: 56/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/532BEB95_0.png is processed: 57/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52CAFAC9_50.png is processed: 58/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52CEE4BD_60.png is processed: 59/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/532BA547_50.png is processed: 60/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/532A6C62_100.png is processed: 61/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52BE2AB4_260.png is processed: 62/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/53258FD9_240.png is processed: 63/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/532D2479_100.png is processed: 64/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5341B6E1_270.png is processed: 65/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52981CE9_220.png is processed: 66/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/531062C1_200.png is processed: 67/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52B28C7D_60.png is processed: 68/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/531FB9D1_90.png is processed: 69/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/532D2479_0.png is processed: 70/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52D490B2_190.png is processed: 71/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52D0D7F4_200.png is processed: 72/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52C1EDFC_90.png is processed: 73/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/532B740E_100.png is processed: 74/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52F24881_40.png is processed: 75/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52F73A21_50.png is processed: 76/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/52
310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/536AA372_220.png is processed: 268/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5439C921_280.png is processed: 269/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5348D075_190.png is processed: 270/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/534EE5E2_100.png is processed: 271/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5394D6F5_200.png is processed: 272/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/539D539E_20.png is processed: 273/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/535579DD_240.png is processed: 274/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/539D539E_140.png is processed: 275/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/53CE1EA1_150.png is processed: 276/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/534E5CC6_200.png is processed: 277/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/543C25D1_30.png is processed: 278/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5453DD4E_280.png is processed: 279/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5377B2D6_100.png is processed: 280/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/53CA1C11_110.png is processed: 281/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5378CC0D_150.png is processed: 282/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5377B2D6_220.png is processed: 283/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/53A0A2E2_200.png is processed: 284/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5452D21E_200.png is processed: 285/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/545210C1_40.png is processed: 286/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/53CE1EA1_190.png is processed: 287/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5347A925_250.png is processed: 288/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/534E71DE_60.png is processed: 289/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/534F59E6_70.png is processed: 290/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/536BC73E_0.png is processed: 291/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5344A031_50.png is processed: 292/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/537AC9D1_270.png is processed: 293/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/534835C5_230.png is processed: 294/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5350AEEA_120.png is processed: 295/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5373DA6D_0.png is processed: 296/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/540B09F2_190.png is processed: 297/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/538B8055_30.png is processed: 298/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/540E0152_230.png is processed: 299/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5369F72D_130.png is processed: 300/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5385A6AD_230.png is processed: 301/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/534F59E6_120.png is processed: 302/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5367F5E6_180.png is processed: 303/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5452D21E_100.png is processed: 304/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/53CE1EA1_0.png is processed: 305/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/53CAA1A9_200.png is processed: 306/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/5347A925_150.png is processed: 307/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/545210C1_0.png is processed: 308/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/53978F0D_0.png is processed: 309/310
# The data sample /content/drive/MyDrive/project/Training_MS_PCEN/NoHW/534F59E6_200.png is processed: 310/310

# %%
import gc
gc.collect()
del img_resized, img_array, images_as_arrays
gc.collect()
# Out:
# 0

# %%
training_data = np.concatenate((training_images_HW, training_images_NoHW), axis=0)
training_labels = np.concatenate((training_labels_HW, training_labels_NoHW), axis=0)

# %%
training_data, training_labels = shuffle(training_data, training_labels, random_state=42)

# %%
import gc
gc.collect()
del training_images_HW, training_images_NoHW, training_labels_HW, training_labels_NoHW
gc.collect()
# Out:
# 0

# %%
plt.figure()
plt.imshow(training_data[90])
plt.title(f'Label {training_labels[90]}')
plt.show()

# %% [markdown]
# # Load validation HW data and assign labels for each data sample (`[1]`)

# %%
#folder_path = '/content/drive/MyDrive/project/Validation_MS_dB/HW'
folder_path = '/content/drive/MyDrive/project/Validation_MS_PCEN/HW'
#folder_path = '/content/drive/MyDrive/project/Validation_MS_PCEN_default/HW'

png_files = glob.glob(os.path.join(folder_path, '*.png'))

images_as_arrays = []
count = 1
for file in png_files:
    with Image.open(file) as img:
        img_array = np.array(img)
        print(f"The data sample {file} is processed: {count}/{len(os.listdir(folder_path))}")
        count = count+1
        images_as_arrays.append(img_array)

validation_images_HW = np.asarray(images_as_arrays)
validation_labels_HW = np.ones(validation_images_HW.shape[0])
# Out:
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/HW/53B64781_100.png is processed: 1/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/HW/53A9FD05_0.png is processed: 2/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/HW/53E94889_160.png is processed: 3/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/HW/53C4C801_0.png is processed: 4/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/HW/53B64781_190.png is processed: 5/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/HW/53E94889_250.png is processed: 6/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/HW/53C821D0_220.png is processed: 7/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/HW/53ED8DE5_150.png is processed: 8/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/HW/53C821D0_50.png is processed: 9/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/HW/53CF14B9_240.png is processed: 10/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/HW/53BFCF59_270.png is processed: 11/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/HW/
100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/HW/541EF71D_50.png is processed: 100/100

# %%
import gc
gc.collect()
del img_resized, img_array, images_as_arrays
gc.collect()
# Out:
# 0

# %% [markdown]
# # Load validation NoHW data and assign labels for each data sample (`[0]`)

# %%
#folder_path = '/content/drive/MyDrive/project/Validation_MS_dB/NoHW'
folder_path = '/content/drive/MyDrive/project/Validation_MS_PCEN/NoHW'
#folder_path = '/content/drive/MyDrive/project/Validation_MS_PCEN_default/NoHW'

png_files = glob.glob(os.path.join(folder_path, '*.png'))

images_as_arrays = []
count = 1
for file in png_files:
    with Image.open(file) as img:
        img_array = np.array(img)
        print(f"The data sample {file} is processed: {count}/{len(os.listdir(folder_path))}")
        count = count+1
        images_as_arrays.append(img_array)

validation_images_NoHW = np.asarray(images_as_arrays)
validation_labels_NoHW = np.zeros(validation_images_NoHW.shape[0])
# Out:
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52A41D90_100.png is processed: 1/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52A59239_270.png is processed: 2/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52DC21CD_30.png is processed: 3/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/529F448D_10.png is processed: 4/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52DA8679_200.png is processed: 5/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/530B0EB1_120.png is processed: 6/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52A9CD09_140.png is processed: 7/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52A1068E_100.png is processed: 8/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/530C27F1_70.png is processed: 9/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52B03DDE_100.png is processed: 10/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52E6B859_280.png is processed: 11/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52EBA2F1_80.png is processed: 12/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52E899FD_230.png is processed: 13/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52DCB8F9_160.png is processed: 14/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52A34399_270.png is processed: 15/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52E93129_30.png is processed: 16/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52DA8679_80.png is processed: 17/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/530ACBE5_140.png is processed: 18/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52A2386A_10.png is processed: 19/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52A41D90_0.png is processed: 20/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52E5D759_140.png is processed: 21/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52EA079D_170.png is processed: 22/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52AB2916_100.png is processed: 23/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52E507ED_100.png is processed: 24/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/530D2511_60.png is processed: 25/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/529F83D5_240.png is processed: 26/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52A41D90_190.png is processed: 27/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52A0F175_130.png is processed: 28/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52AC3B4D_130.png is processed: 29/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52A9984E_270.png is processed: 30/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52A2E4AD_80.png is processed: 31/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52E21B19_100.png is processed: 32/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/529FF7D9_190.png is processed: 33/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52E63644_180.png is processed: 34/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52ED3E45_170.png is processed: 35/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52ED3E45_140.png is processed: 36/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/529E0825_180.png is processed: 37/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/530A7786_160.png is processed: 38/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52E85731_150.png is processed: 39/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52DECF5A_40.png is processed: 40/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52DBC2E2_240.png is processed: 41/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52B03DDE_0.png is processed: 42/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52D5601E_160.png is processed: 43/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52E3B9F2_120.png is processed: 44/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52AB2916_250.png is processed: 45/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52E04785_80.png is processed: 46/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/52AB2916_0.png is processed: 47/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/54492015_80.png is processed: 48/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53E71609_220.png is processed: 49/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/5367C12A_140.png is processed: 50/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/5354B881_250.png is processed: 51/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/5364DEE1_110.png is processed: 52/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/54492015_170.png is processed: 53/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/538F9479_20.png is processed: 54/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53F2A9B5_140.png is processed: 55/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53D42981_250.png is processed: 56/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/54261435_170.png is processed: 57/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/5367F5E6_30.png is processed: 58/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53D42981_50.png is processed: 59/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/5350AEEA_200.png is processed: 60/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/538C9995_160.png is processed: 61/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53D94FDD_50.png is processed: 62/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53D42981_140.png is processed: 63/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/5354B881_40.png is processed: 64/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53472711_110.png is processed: 65/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/5367F5E6_100.png is processed: 66/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53EB9729_260.png is processed: 67/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53472711_70.png is processed: 68/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/5359F072_210.png is processed: 69/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/54261435_280.png is processed: 70/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53D42981_280.png is processed: 71/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/538C05ED_170.png is processed: 72/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/5354B881_100.png is processed: 73/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53656479_30.png is processed: 74/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53472711_130.png is processed: 75/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53E71609_170.png is processed: 76/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/538F9479_150.png is processed: 77/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53F2A9B5_200.png is processed: 78/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/5354B881_200.png is processed: 79/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53890785_190.png is processed: 80/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53908005_10.png is processed: 81/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53F2A9B5_150.png is processed: 82/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53D42981_200.png is processed: 83/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/54261435_130.png is processed: 84/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/538DA141_240.png is processed: 85/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/54261435_50.png is processed: 86/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53E71609_0.png is processed: 87/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53D94FDD_90.png is processed: 88/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/5367F5E6_0.png is processed: 89/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53D42981_100.png is processed: 90/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/538C05ED_100.png is processed: 91/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53D94FDD_0.png is processed: 92/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/5354B881_150.png is processed: 93/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53E71609_50.png is processed: 94/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53663769_240.png is processed: 95/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53D94FDD_130.png is processed: 96/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/5367F5E6_50.png is processed: 97/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/5367D9C5_280.png is processed: 98/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53698329_200.png is processed: 99/100
# The data sample /content/drive/MyDrive/project/Validation_MS_PCEN/NoHW/53F2A9B5_120.png is processed: 100/100

# %%
import gc
gc.collect()
del img_resized, img_array, images_as_arrays
gc.collect()
# Out:
# 0

# %%
validation_data = np.concatenate((validation_images_HW, validation_images_NoHW), axis=0)
validation_labels = np.concatenate((validation_labels_HW, validation_labels_NoHW), axis=0)

# %%
validation_data, validation_labels = shuffle(validation_data, validation_labels, random_state=42)

# %%
import gc
gc.collect()
del validation_images_HW, validation_labels_HW, validation_images_NoHW, validation_labels_NoHW
gc.collect()
# Out:
# 0

# %%
plt.figure()
plt.imshow(validation_data[8])
plt.title(f'Label {validation_labels[8]}')
plt.show()

# %% [markdown]
# ## CNN Model

# %%
def model_scratch(input_shape=(64, 559, 3)):

  ########################## CNN model (Functional API)###############################
  ################################ Model Input #######################################
  model_input = keras.Input(shape=input_shape, name='model_input')
  ####################################################################################
  ####################################################################################
  ########################### First 2D Convolutional Layer ###########################
  model_conv_1 = keras.layers.Conv2D(filters= 32,
                                    kernel_size = (3,3),
                                    strides = (2,2),
                                    activation='relu',
                                    padding='valid',
                                    name = 'conv_layer_1'
                                    )(model_input)
  ####################################################################################
  ####################################################################################
  ########################## Second 2D Convolutional Layer ###########################
  model_conv_2 = keras.layers.Conv2D(64,
                                    kernel_size = (3,3),
                                    strides = (2,2),
                                    activation='relu',
                                    padding='valid',
                                    name = 'conv_layer_2'
                                    )(model_conv_1)
  batch_1 = keras.layers.BatchNormalization(name='bn_1')(model_conv_2)
  dropout_1 = keras.layers.Dropout(0.2, name='dropout1')(batch_1)
  ####################################################################################
  ####################################################################################
  ########################## Third 2D Convolutional Layer ############################
  model_conv_3 = keras.layers.Conv2D(128,
                                    kernel_size = (3,3),
                                    strides = (1,1),
                                    activation='relu',
                                    padding='valid',
                                    name = 'conv_layer_3'
                                    )(dropout_1)
  ####################################################################################
  ####################################################################################
  ########################## Fourth 2D Convolutional Layer ###########################
  model_conv_4 = keras.layers.Conv2D(128,
                                    kernel_size = (3,3),
                                    strides = (2,2),
                                    activation='relu',
                                    padding='valid',
                                    name = 'conv_layer_4'
                                    )(model_conv_3)
  batch_2 = keras.layers.BatchNormalization(name='bn_2')(model_conv_4)
  dropout_2 = keras.layers.Dropout(0.3, name='dropout2')(batch_2)
  ####################################################################################
  ####################################################################################
  ########################### Fifth 2D Convolutional Layer ###########################
  model_conv_5 = keras.layers.Conv2D(128,
                                    kernel_size = (3,3),
                                    strides = (1,1),
                                    activation='relu',
                                    padding='valid',
                                    name = 'conv_layer_5'
                                    )(dropout_2)
  ####################################################################################
  ####################################################################################
  ########################### Sixth 2D Convolutional Layer ###########################
  model_conv_6 = keras.layers.Conv2D(64,
                                    kernel_size = (3,3),
                                    strides = (2,2),
                                    activation='relu',
                                    padding='valid',
                                    name = 'conv_layer_6'
                                    )(model_conv_5)
  batch_3 = keras.layers.BatchNormalization(name='bn_3')(model_conv_6)
  ####################################################################################
  ####################################################################################
  ############################## Global Average Pooling ##############################
  gb_lay = keras.layers.GlobalAveragePooling2D(name='glob_av_pool')(batch_3)
  ####################################################################################
  ####################################################################################
  ############################ First Fully Connected Layer ###########################
  FC_1 = keras.layers.Dense(256,
                            activation='relu',
                            use_bias=True,
                            kernel_initializer='glorot_uniform',
                            bias_initializer='zeros',
                            name='FC1')(gb_lay)
  dropout_3 = keras.layers.Dropout(0.5, name='dropout3')(FC_1)
  ####################################################################################
  ####################################################################################
  ########################### Second Fully Connected Layer ###########################
  FC_2 = keras.layers.Dense(128,
                            activation='relu',
                            use_bias=True,
                            kernel_initializer='glorot_uniform',
                            bias_initializer='zeros',
                            name='FC2')(dropout_3)
  dropout_4 = keras.layers.Dropout(0.2, name='dropout4')(FC_2)
  ####################################################################################
  ####################################################################################
  ################################### Output Layer ###################################
  output_layer = keras.layers.Dense(1, activation='sigmoid')(dropout_4)
  ####################################################################################
  ####################################################################################
  ####################################### Model ######################################
  model_scratch = keras.models.Model(inputs=model_input, outputs=output_layer)
  return model_scratch

# %%
model = model_scratch(input_shape=(224, 224, 3))

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ model_input (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_layer_1 (Conv2D)                │ (None, 111, 111, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_layer_2 (Conv2D)                │ (None, 55, 55, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bn_1 (BatchNormalization)            │ (None, 55, 55, 64)          │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout1 (Dropout)                   │ (None, 55, 55, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_layer_3 (Conv2D)                │ (None, 53, 53, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_layer_4 (Conv2D)                │ (None, 26, 26, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bn_2 (BatchNormalization)            │ (None, 26, 26, 128)         │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout2 (Dropout)                   │ (None, 26, 26, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_layer_5 (Conv2D)                │ (None, 24, 24, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_layer_6 (Conv2D)                │ (None, 11, 11, 64)          │          73,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bn_3 (BatchNormalization)            │ (None, 11, 11, 64)          │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ glob_av_pool                         │ (None, 64)                  │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ FC1 (Dense)                          │ (None, 256)                 │          16,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout3 (Dropout)                   │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ FC2 (Dense)                          │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout4 (Dropout)                   │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 512,897 (1.96 MB)
#  Trainable params: 512,385 (1.95 MB)
#  Non-trainable params: 512 (2.00 KB)

# %% [markdown]
# ## Compile the Model

# %%
def compiling(model,
              optimizer='adam',
              learning_rate=0.001,
              decaying=True):

    if decaying==True:
        initial_learning_rate = learning_rate
        lr_schedule = optimizers.schedules.ExponentialDecay(initial_learning_rate,
                                                                   decay_steps=90,
                                                                  decay_rate=0.75,
                                                                  staircase=True)

        if optimizer=='adam':
            optimizer = optimizers.Adam(learning_rate=lr_schedule)
        elif optimizer=='adagrad':
            optimizer = optimizers.Adagrad(learning_rate=lr_schedule)
        elif optimizer=='rmsprop':
            optimizer = optimizers.RMSprop(learning_rate=lr_schedule)
        elif optimizer=='adamax':
            optimizer = optimizers.Adamax(learning_rate=lr_schedule)
        else:
            raise ValueError("Please enter a valid optimizer")
        loss_fn = keras.losses.BinaryCrossentropy()
        model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])
    else:
        if optimizer=='adam':
            optimizer = optimizers.Adam(learning_rate=learning_rate)
        elif optimizer=='adagrad':
            optimizer = optimizers.Adagrad(learning_rate=learning_rate)
        elif optimizer=='rmsprop':
            optimizer = optimizers.RMSprop(learning_rate=learning_rate)
        elif optimizer=='adamax':
            optimizer = optimizers.Adamax(learning_rate=learning_rate)
        else:
            raise ValueError("Please enter a valid optimizer")

        loss_fn = keras.losses.BinaryCrossentropy()
        model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])

# %%
compiling(model, optimizer='adam', learning_rate=0.001, decaying=True)

# %% [markdown]
# ## Train the Model

# %%
history = model.fit(training_data, training_labels, batch_size=32, epochs=100, validation_data=(validation_data, validation_labels), verbose = 1)
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 23s 539ms/step - accuracy: 0.6722 - loss: 0.5771 - val_accuracy: 0.5350 - val_loss: 3.6946
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.7661 - loss: 0.4954 - val_accuracy: 0.6900 - val_loss: 0.8669
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7466 - loss: 0.5232 - val_accuracy: 0.6800 - val_loss: 0.8369
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.7621 - loss: 0.4937 - val_accuracy: 0.6550 - val_loss: 0.7506
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.7620 - loss: 0.5490 - val_accuracy: 0.7550 - val_loss: 0.5547
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.7621 - loss: 0.5287 - val_accuracy: 0.7550 - val_loss: 0.5324
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7219 - loss: 0.5497 - val_accuracy: 0.7250 - val_loss: 0.5463
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7549 - loss: 0.5222 - val_accuracy: 0.5600 - val_loss: 0.7169
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7857 - loss: 0.4895 - val_accuracy: 0.7600 - val_loss: 0.5386
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7865 - loss: 0.4703 - val_accuracy: 0.7650 - val_loss: 0.5356
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8031 - loss: 0.4786 - val_accuracy: 0.6300 - val_loss: 0.6958
# Epoch 12/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8316 - loss: 0.4107 - val_accuracy: 0.6950 - val_loss: 0.7637
# Epoch 13/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8345 - loss: 0.4280 - val_accuracy: 0.8200 - val_loss: 0.4334
# Epoch 14/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8808 - loss: 0.3575 - val_accuracy: 0.5100 - val_loss: 1.2968
# Epoch 15/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8537 - loss: 0.3497 - val_accuracy: 0.5000 - val_loss: 2.7795
# Epoch 16/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.8870 - loss: 0.3089 - val_accuracy: 0.7250 - val_loss: 0.6337
# Epoch 17/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.8933 - loss: 0.3334 - val_accuracy: 0.7700 - val_loss: 0.5098
# Epoch 18/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9232 - loss: 0.2572 - val_accuracy: 0.7300 - val_loss: 0.6151
# Epoch 19/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9202 - loss: 0.2559 - val_accuracy: 0.6900 - val_loss: 0.7113
# Epoch 20/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9389 - loss: 0.2157 - val_accuracy: 0.6200 - val_loss: 1.1999
# Epoch 21/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9313 - loss: 0.2398 - val_accuracy: 0.6150 - val_loss: 2.7680
# Epoch 22/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9337 - loss: 0.1954 - val_accuracy: 0.6000 - val_loss: 2.8939
# Epoch 23/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9483 - loss: 0.1676 - val_accuracy: 0.6100 - val_loss: 6.1545
# Epoch 24/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9600 - loss: 0.1270 - val_accuracy: 0.6150 - val_loss: 4.0782
# Epoch 25/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9519 - loss: 0.1457 - val_accuracy: 0.6450 - val_loss: 2.5630
# Epoch 26/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9364 - loss: 0.1584 - val_accuracy: 0.8800 - val_loss: 0.3093
# Epoch 27/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9485 - loss: 0.1337 - val_accuracy: 0.6400 - val_loss: 1.7583
# Epoch 28/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9560 - loss: 0.1472 - val_accuracy: 0.7850 - val_loss: 0.5722
# Epoch 29/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9493 - loss: 0.1488 - val_accuracy: 0.8800 - val_loss: 0.3382
# Epoch 30/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.
# Epoch 69/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9892 - loss: 0.0290 - val_accuracy: 0.8950 - val_loss: 0.3772
# Epoch 70/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9939 - loss: 0.0304 - val_accuracy: 0.9000 - val_loss: 0.3925
# Epoch 71/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9770 - loss: 0.0500 - val_accuracy: 0.8900 - val_loss: 0.3871
# Epoch 72/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9992 - loss: 0.0250 - val_accuracy: 0.8950 - val_loss: 0.3853
# Epoch 73/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9950 - loss: 0.0209 - val_accuracy: 0.9000 - val_loss: 0.3777
# Epoch 74/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9965 - loss: 0.0217 - val_accuracy: 0.9050 - val_loss: 0.3773
# Epoch 75/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9908 - loss: 0.0356 - val_accuracy: 0.8950 - val_loss: 0.4046
# Epoch 76/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9798 - loss: 0.0475 - val_accuracy: 0.9000 - val_loss: 0.3917
# Epoch 77/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9930 - loss: 0.0327 - val_accuracy: 0.8950 - val_loss: 0.3770
# Epoch 78/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9892 - loss: 0.0267 - val_accuracy: 0.9050 - val_loss: 0.3705
# Epoch 79/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9989 - loss: 0.0207 - val_accuracy: 0.9050 - val_loss: 0.3644
# Epoch 80/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9840 - loss: 0.0453 - val_accuracy: 0.8950 - val_loss: 0.3738
# Epoch 81/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9897 - loss: 0.0265 - val_accuracy: 0.9000 - val_loss: 0.3545
# Epoch 82/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9937 - loss: 0.0243 - val_accuracy: 0.8950 - val_loss: 0.3559
# Epoch 83/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9925 - loss: 0.0236 - val_accuracy: 0.9100 - val_loss: 0.3560
# Epoch 84/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9817 - loss: 0.0388 - val_accuracy: 0.8950 - val_loss: 0.3523
# Epoch 85/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9918 - loss: 0.0248 - val_accuracy: 0.9000 - val_loss: 0.3557
# Epoch 86/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9892 - loss: 0.0290 - val_accuracy: 0.9100 - val_loss: 0.3531
# Epoch 87/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9940 - loss: 0.0264 - val_accuracy: 0.9000 - val_loss: 0.3553
# Epoch 88/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9903 - loss: 0.0292 - val_accuracy: 0.9000 - val_loss: 0.3598
# Epoch 89/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9963 - loss: 0.0247 - val_accuracy: 0.9000 - val_loss: 0.3618
# Epoch 90/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9960 - loss: 0.0238 - val_accuracy: 0.9000 - val_loss: 0.3598
# Epoch 91/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9986 - loss: 0.0187 - val_accuracy: 0.9050 - val_loss: 0.3615
# Epoch 92/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9954 - loss: 0.0235 - val_accuracy: 0.9050 - val_loss: 0.3623
# Epoch 93/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9946 - loss: 0.0194 - val_accuracy: 0.9100 - val_loss: 0.3594
# Epoch 94/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9859 - loss: 0.0301 - val_accuracy: 0.9100 - val_loss: 0.3595
# Epoch 95/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9827 - loss: 0.0415 - val_accuracy: 0.8950 - val_loss: 0.3626
# Epoch 96/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9921 - loss: 0.0318 - val_accuracy: 0.9000 - val_loss: 0.3650
# Epoch 97/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9954 - loss: 0.0244 - val_accuracy: 0.9000 - val_loss: 0.3626
# Epoch 98/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9840 - loss: 0.0418 - val_accuracy: 0.9050 - val_loss: 0.3615
# Epoch 99/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9907 - loss: 0.0277 - val_accuracy: 0.9100 - val_loss: 0.3673
# Epoch 100/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9962 - loss: 0.0181 - val_accuracy: 0.9050 - val_loss: 0.3696

# %% [markdown]
# # Save

# %%
from tensorflow.keras.models import model_from_json
# Save model after training finished (see for more details,
# see: https://github.com/aaolcay/save_load_NN_model)
# serialize model to JSON
model_json = model.to_json()
with open("/content/drive/MyDrive/project/model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("/content/drive/MyDrive/project/model.weights.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# # Load

# %%
json_file = open('/content/drive/MyDrive/project/model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("/content/drive/MyDrive/project/model.weights.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
predicted_labels = loaded_model.predict(validation_data)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step

# %%
predicted_labels[predicted_labels>=0.5] = 1
predicted_labels[predicted_labels<0.5] = 0
predicted_labels = predicted_labels[:,0]
a = predicted_labels==validation_labels
len(np.where(a==True)[0])/validation_labels.shape[0]
# Out:
# 0.905
